# %%
import importlib
import optimized_fractals as of
import fractal_parameters 
from fractal_parameters import *
import palettes
# Reload modules actively being developed
importlib.reload(of)
importlib.reload(fractal_parameters)
importlib.reload(palettes)
import optimized_fractals as of
from fractal_parameters import *

# %%
# Generate the mandelbrot set
resolution = 2048


of.generate_standard_fractal(
    resolution,
    resolution,
    0.00035 * 4,
    -0.612125,
    0.0,
    200,
    1000,
    of.make_coloring(1, palettes.nebula, 50),
    mandelbrot_parameters,
    "gallery/mandelbrot.png"
)

# %%
# Best of all parameters
resolution = 2048

of.generate_standard_fractal(
    resolution,
    resolution,
    0.0026220928702218446 / 2,
    -0.20321832142202192,
    -0.431851184262184,
    200,
    1000,
    of.make_coloring(1, palettes.nebula, 50),
    best_all_parameters,
    "gallery/best_all.png"
)

# %%
# Best of real parameters
resolution = 2048

of.generate_standard_fractal(
    resolution,
    resolution,
    0.006386914673976314 / 2,
    -0.35,
    0.0,
    200,
    1000,
    of.make_coloring(1, palettes.nebula, 50),
    best_real_parameters,
    "gallery/best_real.png"
)

# %%
# Best of first 16 parameters
resolution = 2048



of.generate_standard_fractal(
    resolution,
    resolution,
    0.014068986056655191 / 2,
    0.0,
    0.0,
    200,
    1000,
    of.make_coloring(1, palettes.event_horizon, 70),
    best_first_16_parameters,
    "gallery/best_first_16.png"
)

# %%
# Best of first 16 real parameters
resolution = 2048

of.generate_standard_fractal(
    resolution,
    resolution,
    0.03674392126880555 / 2,
    0.0,
    0.0,
    20000,
    10000,
    of.make_coloring(1, palettes.nebula, 50),
    best_first_16_real_parameters,
    "gallery/best_first_16_real.png"
)

# %%
# Spiral of spirals found in the best fractal of the first 16 parameters

resolution = 2048

of.generate_standard_fractal(
    resolution,
    resolution,
    7.164533781696647e-05 / 4,
    1.4928518937075785,
    -1.5829525208342352,
    20000,
    1000,
    of.make_coloring(1, palettes.quazar, 70),
    best_first_16_parameters,
    "gallery/spiral_squared.png"
)

# %%
# Wack spirals found in the best fractal of the first 16 parameters

resolution = 2048

of.generate_standard_fractal(
    resolution,
    resolution,
    0.00018711587611377936 / 3.5,
    1.7642954805050868,
    -1.4159377364174779,
    20000,
    1000,
    of.make_coloring(1, palettes.quazar, 70),
    best_first_16_parameters,
    "gallery/dancing_octipi.png"
)

# %%
# Spirally tunnel

resolution = 2048

of.generate_standard_fractal(
    resolution,
    resolution,
    9.315950916789492e-06 / 2,
    -1.0238636800871386,
    -3.987701872551214,
    20000,
    1000,
    of.make_coloring(1, palettes.quazar, 50),
    best_first_16_parameters,
    "gallery/tunnel.png"
)

# %%
# Julia set generation

resolution = 2048

of.generate_standard_julia(
    resolution,
    resolution,
    4.0 / resolution,
    0.0,
    0.0,
    1000,
    10000,
    70,
    [
    14, 21, 101,
    165, 212, 225,
    244, 150, 6,
    69, 27, 48
    ],
    -0.8,
    0.156,
    mandelbrot_parameters,
    "gallery/julia_set.png"
)

# %%
# Spiral of spirals found in the best fractal of the first 16 parameters

resolution = 2048

of.generate_standard_fractal(
    resolution,
    resolution,
    0.014068986056655191 / 2,
    0.0,
    0.0,
    200,
    1000,
    of.make_coloring(1, palettes.stony_beach, 70),
    best_first_16_parameters,
    "images/test.png"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 13
#       1 # Spiral of spirals found in the best fractal of the first 16 parameters
#       3 resolution = 2048
#       5 of.generate_standard_fractal(
#       6     resolution,
#       7     resolution,
#       8     0.014068986056655191 / 2,
#       9     0.0,
#      10     0.0,
#      11     200,
#      12     1000,
# ---> 13     of.make_coloring(1, palettes.stony_beach, 70),
#      14     best_first_16_parameters,
#      15     "images/test.png"
#      16 )
#
# AttributeError: module 'palettes' has no attribute 'stony_beach'
