# %%
import importlib
import optimized_fractals as of
import fractal_parameters 
from fractal_parameters import *
import palettes
# Reload modules actively being developed
importlib.reload(of)
importlib.reload(fractal_parameters)
importlib.reload(palettes)
import optimized_fractals as of
from fractal_parameters import *

# %%
# Generate the mandelbrot set
resolution = 8192


of.generate_standard_fractal(
    resolution,
    resolution,
    0.00035,
    -0.612125,
    0.0,
    200,
    1000,
    of.make_coloring(1, palettes.nebula, 50),
    mandelbrot_parameters,
    "gallery/mandelbrot.png"
)

# %%
# Best of all parameters
resolution = 1024 * 8

of.generate_standard_fractal(
    resolution,
    resolution,
    0.0026220928702218446 / 8,
    -0.20321832142202192,
    -0.431851184262184,
    200,
    1000,
    of.make_coloring(1, palettes.nebula, 50),
    best_all_parameters,
    "gallery/best_all.png"
)

# %%
# Best of real parameters
resolution = 1024 * 8

of.generate_standard_fractal(
    resolution,
    resolution,
    0.006386914673976314 / 8,
    -0.35,
    0.0,
    200,
    1000,
    of.make_coloring(1, palettes.nebula, 50),
    best_real_parameters,
    "gallery/best_real.png"
)

# %%
# Best of first 16 parameters
resolution = 1024 * 8

of.generate_standard_fractal(
    resolution,
    resolution,
    0.014068986056655191 / 8,
    0.0,
    0.0,
    200,
    1000,
    of.make_coloring(1, palettes.nebula, 50),
    best_first_16_parameters,
    "gallery/best_first_16.png"
)

# %%
# Best of first 16 real parameters
resolution = 1024 * 8

of.generate_standard_fractal(
    resolution,
    resolution,
    0.03674392126880555 / 8,
    0.0,
    0.0,
    20000,
    10000,
    of.make_coloring(1, palettes.nebula, 50),
    best_first_16_real_parameters,
    "gallery/best_first_16_real.png"
)

# %%
resolution = 8192
color_palette = [
    51, 51, 255,
    0, 153, 200,
    0, 230, 0,
    51, 51, 255
]

cr = 0.375
ci = 0.282

of.generate_standard_julia(
    resolution,
    resolution,
    0.00035 / 8,
    0.0,
    0.0,
    200,
    1000,
    50,
    color_palette,
    cr,
    ci,
    best_fractal_parameters,
    "images/julia_test.png"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 24
#       9 cr = 0.375
#      10 ci = 0.282
#      12 of.generate_standard_julia(
#      13     resolution,
#      14     resolution,
#      15     0.00035 / 8,
#      16     0.0,
#      17     0.0,
#      18     200,
#      19     1000,
#      20     50,
#      21     color_palette,
#      22     cr,
#      23     ci,
# ---> 24     best_fractal_parameters,
#      25     "images/julia_test.png"
#      26 )
#
# NameError: name 'best_fractal_parameters' is not defined
